# %%
# Paths
dbutils.widgets.text("BRONZE_PATH", "s3://nyc-tlc-data-398563707364/bronze/")
dbutils.widgets.text("SILVER_PATH", "s3://nyc-tlc-data-398563707364/silver/")
dbutils.widgets.text("GOLD_PATH", "s3://nyc-tlc-data-398563707364/silver/")
dbutils.widgets.text("QUARANTINE_PATH", "s3://nyc-tlc-data-398563707364/quarantine/")
dbutils.widgets.text("SCHEMA_PATH", "s3://nyc-tlc-data-398563707364/_schemas/")
dbutils.widgets.text("CHECKPOINT_PATH", "s3://nyc-tlc-data-398563707364/_checkpoints/")

# Logging tables
dbutils.widgets.text("LOG_TABLE_BRONZE", "nyc_taxi.logs.bronze_ingestion_logs")
dbutils.widgets.text("LOG_TABLE_SILVER", "nyc_taxi.logs.silver_ingestion_logs")
dbutils.widgets.text("LOG_TABLE_GOLD", "nyc_taxi.logs.gold_ingestion_logs")

# Run ID (optional, auto-generate)
import uuid
dbutils.widgets.text("RUN_ID", str(uuid.uuid4()))
